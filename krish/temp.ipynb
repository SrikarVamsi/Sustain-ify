# %%
import time
from langchain_core.language_models.chat_models import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
import base64

import os

os.environ['GOOGLE_API_KEY'] = "AIzaSyAUM75YmpuvV6o1MJp9UBawfhqyWtQ1K_s"


llm = ChatGoogleGenerativeAI(model='gemini-1.5-pro')

# %% [markdown]
# # stable diffusion 3 (worked. but not in my lap + need to use another model)
# # fast api  ✅ (input is b64b encoded image)
# # rag

# %% [markdown]
# ### SD -> Control net

# %%
with open('output_prod.json', 'w') as f:
    f.write(json_string)

# %%
import torch
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", revision="fp16", torch_dtype=torch.float16)

# %% [markdown]
# # jst checking json outputs👇

# %%
import json
with open('output_json/output_prod_ruffless.json', 'r') as f:
    data = json.load(f)
print(data)
# Out:
# {
#     "Projects": {
#         "Easy": {
#             "DIY_Product": "This project uses a Ruffles Cheddar & Sour Cream chips bag to create a simple snack bowl. It's perfect for holding a single serving of chips, pretzels, or other snacks, and adds a fun, recycled touch to your snacking experience.",
#             "Materials_Required": [
#                 {
#                     "Material": "Empty Ruffles Cheddar & Sour Cream chips bag",
#                     "Quantity": "1"
#                 },
#                 {
#                     "Material": "Scissors",
#                     "Quantity": "1"
#                 }
#             ],
#             "Steps": [
#                 {
#                     "Step_Number": 1,
#                     "Description": "Carefully wash and dry the empty Ruffles Cheddar & Sour Cream chips bag.",
#                     "Estimated_Time": "5 minutes",
#                     "Safety_Tips": "Be careful of any sharp edges on the bag opening."
# ...

# %%
temp = "{\n    \"Projects\": {\n        \"Easy\": {\n            \"DIY_Product\": \"Doritos Nacho Snack Mix\",\n            \"Materials_Required\": [\n                {\n                    \"Material\": \"Doritos Poppin' Jalape�o chips\",\n                    \"Quantity\": \"1 bag\"\n                },\n                {\n                    \"Material\": \"Pretzel sticks\",\n                    \"Quantity\": \"1 cup\"\n                },\n                {\n                    \"Material\": \"Peanuts\",\n                    \"Quantity\": \"1/2 cup\"\n                }\n            ],\n            \"Steps\": [\n                {\n                    \"Step_Number\": 1,\n                    \"Description\": \"Pour the entire bag of Doritos Poppin' Jalape�o chips into a large bowl.\",\n                    \"Estimated_Time\": \"2 minutes\",\n                    \"Safety_Tips\": \"None\"\n                },\n                {\n                    \"Step_Number\": 2,\n                    \"Description\": \"Add the pretzel sticks and peanuts to the bowl.\",\n                    \"Estimated_Time\": \"1 minute\",\n                    \"Safety_Tips\": \"None\"\n                },\n                {\n                    \"Step_Number\": 3,\n                    \"Description\": \"Mix all ingredients well with a spoon until evenly distributed.\",\n                    \"Estimated_Time\": \"2 minutes\",\n                    \"Safety_Tips\": \"None\"\n                }\n            ],\n            \"Difficulty_Level\": {\n                \"Level\": \"Easy\",\n                \"Explanation\": \"This recipe requires no cooking or special skills. It's a simple combination of ingredients for a quick and tasty snack.\"\n            }\n        },\n        \"Medium\": {\n            \"DIY_Product\": \"Doritos Crusted Chicken Tenders\",\n            \"Materials_Required\": [\n                {\n                    \"Material\": \"Doritos Poppin' Jalape�o chips\",\n                    \"Quantity\": \"1 bag\"\n                },\n                {\n                    \"Material\": \"Chicken tenders\",\n                    \"Quantity\": \"1 pound\"\n                },\n                {\n                    \"Material\": \"Eggs\",\n                    \"Quantity\": \"2\"\n                },\n                {\n                    \"Material\": \"All-purpose flour\",\n                    \"Quantity\": \"1/2 cup\"\n                },\n                {\n                    \"Material\": \"Salt and pepper\",\n                    \"Quantity\": \"To taste\"\n                }\n            ],\n            \"Steps\": [\n                {\n                    \"Step_Number\": 1,\n                    \"Description\": \"Preheat oven to 400�F (200�C). Line a baking sheet with parchment paper.\",\n                    \"Estimated_Time\": \"10 minutes\",\n                    \"Safety_Tips\": \"Be careful when handling hot oven.\"\n                },\n                {\n                    \"Step_Number\": 2,\n                    \"Description\": \"Crush the Doritos chips into crumbs using a rolling pin or by pulsing them in a food processor.\",\n                    \"Estimated_Time\": \"5 minutes\",\n                    \"Safety_Tips\": \"If using a food processor, be careful not to over-process the chips into a paste.\"\n                },\n                {\n                    \"Step_Number\": 3,\n                    \"Description\": \"Set up a breading station with three shallow dishes: one with flour, one with beaten eggs, and one with the crushed Doritos.\",\n                    \"Estimated_Time\": \"3 minutes\",\n                    \"Safety_Tips\": \"None\"\n                },\n                {\n                    \"Step_Number\": 4,\n                    \"Description\": \"Season the chicken tenders with salt and pepper.\",\n                    \"Estimated_Time\": \"2 minutes\",\n                    \"Safety_Tips\": \"None\"\n                },\n                {\n                    \"Step_Number\": 5,\n                    \"Description\": \"Dredge each chicken tender in flour, then dip in the egg mixture, and finally coat thoroughly with the Doritos crumbs.\",\n                    \"Estimated_Time\": \"5 minutes\",\n                    \"Safety_Tips\": \"Wash hands thoroughly after handling raw chicken.\"\n                },\n                {\n                    \"Step_Number\": 6,\n                    \"Description\": \"Place the breaded chicken tenders on the prepared baking sheet and bake for 20-25 minutes, or until golden brown and cooked through.\",\n                    \"Estimated_Time\": \"25 minutes\",\n                    \"Safety_Tips\": \"Use oven mitts when handling hot baking sheet.\"\n                }\n            ],\n            \"Difficulty_Level\": {\n                \"Level\": \"Medium\",\n                \"Explanation\": \"This recipe involves breading and baking, requiring some cooking experience. It takes a bit longer than the easy recipe but is still manageable for most home cooks.\"\n            }\n        },\n        \"Hard\": {\n            \"DIY_Product\": \"Doritos Poppin' Jalape�o Arancini\",\n            \"Materials_Required\": [\n                {\n                    \"Material\": \"Doritos Poppin' Jalape�o chips\",\n                    \"Quantity\": \"1 bag\"\n                },\n                {\n                    \"Material\": \"Cooked risotto\",\n                    \"Quantity\": \"2 cups\"\n                },\n                {\n                    \"Material\": \"Mozzarella cheese, cubed\",\n                    \"Quantity\": \"1/2 cup\"\n                },\n                {\n                    \"Material\": \"All-purpose flour\",\n                    \"Quantity\": \"1/2 cup\"\n                },\n                {\n                    \"Material\": \"Eggs\",\n                    \"Quantity\": \"2\"\n                },\n                {\n                    \"Material\": \"Breadcrumbs\",\n                    \"Quantity\": \"1 cup\"\n                },\n                {\n                    \"Material\": \"Vegetable oil, for frying\",\n                    \"Quantity\": \"As needed\"\n                }\n            ],\n            \"Steps\": [\n                {\n                    \"Step_Number\": 1,\n                    \"Description\": \"Crush the Doritos chips into fine crumbs using a food processor or by placing them in a zip-top bag and crushing them with a rolling pin.\",\n                    \"Estimated_Time\": \"5 minutes\",\n                    \"Safety_Tips\": \"If using a food processor, be careful not to over-process the chips into a paste.\"\n                },\n                {\n                    \"Step_Number\": 2,\n                    \"Description\": \"Line a baking sheet with parchment paper and set aside.\",\n                    \"Estimated_Time\": \"2 minutes\",\n                    \"Safety_Tips\": \"None\"\n                },\n                {\n                    \"Step_Number\": 3,\n                    \"Description\": \"Divide the cooled risotto into equal portions. Flatten each portion in your hand and place a cube of mozzarella in the center.\",\n                    \"Estimated_Time\": \"5 minutes\",\n                    \"Safety_Tips\": \"None\"\n                },\n                {\n                    \"Step_Number\": 4,\n                    \"Description\": \"Shape the risotto around the cheese, forming small balls.\",\n                    \"Estimated_Time\": \"5 minutes\",\n                    \"Safety_Tips\": \"None\"\n                },\n                {\n                    \"Step_Number\": 5,\n                    \"Description\": \"Set up a breading station with three shallow dishes: one with flour, one with beaten eggs, and one with the crushed Doritos.\",\n                    \"Estimated_Time\": \"3 minutes\",\n                    \"Safety_Tips\": \"None\"\n                },\n                {\n                    \"Step_Number\": 6,\n                    \"Description\": \"Roll each arancini ball in flour, then dip in the egg mixture, and finally coat completely with the Doritos crumbs.\",\n                    \"Estimated_Time\": \"10 minutes\",\n                    \"Safety_Tips\": \"None\"\n                },\n                {\n                    \"Step_Number\": 7,\n                    \"Description\": \"Heat the vegetable oil in a large pot or deep fryer to 350�F (175�C).\",\n                    \"Estimated_Time\": \"10 minutes\",\n                    \"Safety_Tips\": \"Be extremely careful when heating and handling hot oil. Never leave unattended.\"\n                },\n                {\n                    \"Step_Number\": 8,\n                    \"Description\": \"Carefully lower a few arancini balls at a time into the hot oil. Fry for 3-5 minutes, or until golden brown and heated through.\",\n                    \"Estimated_Time\": \"10 minutes\",\n                    \"Safety_Tips\": \"Use a slotted spoon to carefully lower and retrieve the arancini balls from the hot oil. Avoid overcrowding the pot.\"\n                },\n                {\n                    \"Step_Number\": 9,\n                    \"Description\": \"Remove the cooked arancini balls from the oil and place them on the prepared baking sheet to drain any excess oil.\",\n                    \"Estimated_Time\": \"2 minutes\",\n                    \"Safety_Tips\": \"Use caution when handling the hot arancini balls and baking sheet.\"\n                }\n            ],\n            \"Difficulty_Level\": {\n                \"Level\": \"Hard\",\n                \"Explanation\": \"This recipe requires advanced cooking techniques like deep-frying and working with risotto. It's time-consuming and requires careful attention to detail, making it suitable for experienced cooks.\"\n            }\n        }\n    }\n}"
